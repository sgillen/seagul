# %%
import seagul.envs
import ray
import ray.rllib.agents.ppo as ppo
from ray.tune.logger import pretty_print
import tensorflow as tf
import time
from tqdm import trange

from ray.tune.registry import register_env
from seagul.envs.mujoco.five_link import FiveLinkWalkerEnv

env_name = "Walker2DBulletEnv-v0"

### Needed for custom envs only 
def env_creator(env_config):
    return FiveLinkWalkerEnv()  # return an env instance

register_env("five_link-v3", env_creator)
####


ray.init()
config = ppo.DEFAULT_CONFIG.copy()
config["num_gpus"] = 0
config["num_workers"] = 1
config["eager"] = False
config["model"]["fcnet_hiddens"] = []

trainer = ppo.PPOTrainer(config=config, env=env_name)
# Out:
# 2019-11-13 10:28:38,994	WARNING worker.py:1268 -- WARNING: Not updating worker name since `setproctitle` is not installed. Install this with `pip install setproctitle` (or ray[debug]) to enable monitoring of worker processes.
# 2019-11-13 10:28:38,996	INFO resource_spec.py:205 -- Starting Ray with 7.08 GiB memory available for workers and up to 3.56 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2019-11-13 10:28:39,350	INFO trainer.py:345 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-dfc333af6e07> in <module>
#      27 config["model"]["fcnet_hiddens"] = []
#      28
# ---> 29 trainer = ppo.PPOTrainer(config=config, env=env_name)
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py in __init__(self, config, env, logger_creator)
#      88
#      89         def __init__(self, config=None, env=None, logger_creator=None):
# ---> 90             Trainer.__init__(self, config, env, logger_creator)
#      91
#      92         def _init(self, config, env_creator):
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/agents/trainer.py in __init__(self, config, env, logger_creator)
#     370             logger_creator = default_logger_creator
#     371
# --> 372         Trainable.__init__(self, config, logger_creator)
#     373
#     374     @classmethod
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/tune/trainable.py in __init__(self, config, logger_creator)
#      94         self._restored = False
#      95         start_time = time.time()
# ---> 96         self._setup(copy.deepcopy(self.config))
#      97         setup_time = time.time() - start_time
#      98         if setup_time > SETUP_TIME_THRESHOLD:
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/agents/trainer.py in _setup(self, config)
#     490
#     491         with get_scope():
# --> 492             self._init(self.config, self.env_creator)
#     493
#     494             # Evaluation related
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py in _init(self, config, env_creator)
#     107             else:
#     108                 self.workers = self._make_workers(env_creator, policy, config,
# --> 109                                                   self.config["num_workers"])
#     110             if make_policy_optimizer:
#     111                 self.optimizer = make_policy_optimizer(self.workers, config)
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/agents/trainer.py in _make_workers(self, env_creator, policy, config, num_workers)
#     535             config,
#     536             num_workers=num_workers,
# --> 537             logdir=self.logdir)
#     538
#     539     @DeveloperAPI
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/evaluation/worker_set.py in __init__(self, env_creator, policy, trainer_config, num_workers, logdir, _setup)
#      62             # Always create a local worker
#      63             self._local_worker = self._make_worker(
# ---> 64                 RolloutWorker, env_creator, policy, 0, self._local_config)
#      65
#      66             # Create a number of remote workers
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/evaluation/worker_set.py in _make_worker(self, cls, env_creator, policy, worker_index, config)
#     218             seed=(config["seed"] + worker_index)
#     219             if config["seed"] is not None else None,
# --> 220             _fake_sampler=config.get("_fake_sampler", False))
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py in __init__(self, env_creator, policy, policy_mapping_fn, policies_to_train, tf_session_creator, batch_steps, batch_mode, episode_horizon, preprocessor_pref, sample_async, compress_observations, num_envs, observation_filter, clip_rewards, clip_actions, env_config, model_config, policy_config, worker_index, monitor_path, log_dir, log_level, callbacks, input_creator, input_evaluation, output_creator, remote_worker_envs, remote_env_batch_wait_ms, soft_horizon, no_done_at_end, seed, _fake_sampler)
#     269         self._fake_sampler = _fake_sampler
#     270
# --> 271         self.env = _validate_env(env_creator(env_context))
#     272         if isinstance(self.env, MultiAgentEnv) or \
#     273                 isinstance(self.env, BaseEnv):
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/ray/rllib/agents/trainer.py in <lambda>(env_config)
#     468             else:
#     469                 import gym  # soft dependency
# --> 470                 self.env_creator = lambda env_config: gym.make(env)
#     471         else:
#     472             self.env_creator = lambda env_config: None
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/gym/envs/registration.py in make(id, **kwargs)
#     154
#     155 def make(id, **kwargs):
# --> 156     return registry.make(id, **kwargs)
#     157
#     158 def spec(id):
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/gym/envs/registration.py in make(self, path, **kwargs)
#      99             logger.info('Making new env: %s', path)
#     100         spec = self.spec(path)
# --> 101         env = spec.make(**kwargs)
#     102         # We used to have people override _reset/_step rather than
#     103         # reset/step. Set _gym_disable_underscore_compat = True on
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/gym/envs/registration.py in make(self, **kwargs)
#      71         else:
#      72             cls = load(self.entry_point)
# ---> 73             env = cls(**_kwargs)
#      74
#      75         # Make the enviroment aware of which spec it came from.
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/gym/envs/mujoco/walker2d.py in __init__(self)
#       6
#       7     def __init__(self):
# ----> 8         mujoco_env.MujocoEnv.__init__(self, "walker2d.xml", 4)
#       9         utils.EzPickle.__init__(self)
#      10
#
# ~/miniconda3/envs/sym/lib/python3.6/site-packages/gym/envs/mujoco/mujoco_env.py in __init__(self, model_path, frame_skip)
#      45             raise IOError("File %s does not exist" % fullpath)
#      46         self.frame_skip = frame_skip
# ---> 47         self.model = mujoco_py.load_model_from_path(fullpath)
#      48         self.sim = mujoco_py.MjSim(self.model)
#      49         self.data = self.sim.data
#
# AttributeError: module 'mujoco_py' has no attribute 'load_model_from_path'

# %%
# Can optionally call trainer.restore(path) to load a checkpoint.

for i in trange(500):
   # Perform one iteration of training the policy with ARS
    result = trainer.train()

checkpoint = trainer.save()
print("checkpoint saved at", checkpoint)
print(pretty_print(result))
ray.shutdown()
# Out:
# Couldn't import `requests` library. Be sure to install it on the client side.
# Couldn't import `requests` library. Be sure to install it on the client side.
# Traceback (most recent call last):
#   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
#     import requests  # `requests` is not part of stdlib.
#   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
#     import chardet
# ModuleNotFoundError: No module named 'chardet'
# /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2019-11-11 11:27:28,537	INFO resource_spec.py:205 -- Starting Ray with 2.93 GiB memory available for workers and up to 1.47 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2019-11-11 11:27:28,888	INFO trainer.py:344 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 2019-11-11 11:27:30,048	INFO rollout_worker.py:768 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f0e09f125c0>}
# 2019-11-11 11:27:30,048	INFO rollout_worker.py:769 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f0e09f12278>}
# 2019-11-11 11:27:30,049	INFO rollout_worker.py:370 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f0e11681b00>}
# 2019-11-11 11:27:30,070	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=6449) 2019-11-11 11:27:30,097	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6449) 2019-11-11 11:27:30,115	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6449) Traceback (most recent call last):
# (pid=6449)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6449)     import requests  # `requests` is not part of stdlib.
# (pid=6449)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6449)     import chardet
# (pid=6449) ModuleNotFoundError: No module named 'chardet'
# (pid=6449) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6449)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6449) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6449)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6449) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6449)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6449) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6449)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6449) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6449)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6449) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6449)   np_resource = np.dtype([("resource", np.ubyte, 1)])
#   0%|          | 0/500 [00:00<?, ?it/s]
# (pid=6449) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
# (pid=6449)   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# (pid=6449) 2019-11-11 11:27:32,211	INFO rollout_worker.py:467 -- Generating sample batch of size 200
# (pid=6449) 2019-11-11 11:27:32,212	INFO sampler.py:310 -- Raw obs from env: { 0: { 'agent0': np.ndarray((17,), dtype=float64, min=-0.005, max=1.246, mean=0.073)}}
# (pid=6449) 2019-11-11 11:27:32,212	INFO sampler.py:311 -- Info return from env: {0: {'agent0': None}}
# (pid=6449) 2019-11-11 11:27:32,212	INFO sampler.py:409 -- Preprocessed obs: np.ndarray((17,), dtype=float64, min=-0.005, max=1.246, mean=0.073)
# (pid=6449) 2019-11-11 11:27:32,212	INFO sampler.py:413 -- Filtered obs: np.ndarray((17,), dtype=float64, min=-0.005, max=1.246, mean=0.073)
# (pid=6449) 2019-11-11 11:27:32,213	INFO sampler.py:528 -- Inputs to compute_actions():
# (pid=6449)
# (pid=6449) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=6449)                                   'env_id': 0,
# (pid=6449)                                   'info': None,
# (pid=6449)                                   'obs': np.ndarray((17,), dtype=float64, min=-0.005, max=1.246, mean=0.073),
# (pid=6449)                                   'prev_action': np.ndarray((6,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=6449)                                   'prev_reward': 0.0,
# (pid=6449)                                   'rnn_state': []},
# (pid=6449)                         'type': 'PolicyEvalData'}]}
# (pid=6449)
# (pid=6449) 2019-11-11 11:27:32,213	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=6449) 2019-11-11 11:27:32,240	INFO sampler.py:555 -- Outputs of compute_actions():
# (pid=6449)
# (pid=6449) { 'default_policy': ( np.ndarray((1, 6), dtype=float32, min=-1.996, max=1.661, mean=0.259),
# (pid=6449)                       [],
# (pid=6449)                       { 'action_logp': np.ndarray((1,), dtype=float32, min=-9.382, max=-9.382, mean=-9.382),
# (pid=6449)                         'action_prob': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=6449)                         'behaviour_logits': np.ndarray((1, 12), dtype=float32, min=-0.005, max=0.004, mean=0.0),
# (pid=6449)                         'vf_preds': np.ndarray((1,), dtype=float32, min=0.004, max=0.004, mean=0.004)})}
# (pid=6449)
# (pid=6449) 2019-11-11 11:27:32,261	INFO sample_batch_builder.py:161 -- Trajectory fragment after postprocess_trajectory():
# (pid=6449)
# (pid=6449) { 'agent0': { 'data': { 'action_logp': np.ndarray((23,), dtype=float32, min=-9.57, max=-5.695, mean=-7.638),
# (pid=6449)                         'action_prob': np.ndarray((23,), dtype=float32, min=0.0, max=0.003, mean=0.001),
# (pid=6449)                         'actions': np.ndarray((23, 6), dtype=float32, min=-2.51, max=2.553, mean=0.041),
# (pid=6449)                         'advantages': np.ndarray((23,), dtype=float32, min=-1.918, max=1.904, mean=0.572),
# (pid=6449)                         'agent_index': np.ndarray((23,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=6449)                         'behaviour_logits': np.ndarray((23, 12), dtype=float32, min=-0.141, max=0.136, mean=0.007),
# (pid=6449)                         'dones': np.ndarray((23,), dtype=bool, min=0.0, max=1.0, mean=0.043),
# (pid=6449)                         'eps_id': np.ndarray((23,), dtype=int64, min=457267029.0, max=457267029.0, mean=457267029.0),
# (pid=6449)                         'infos': np.ndarray((23,), dtype=object, head={}),
# (pid=6449)                         'new_obs': np.ndarray((23, 17), dtype=float32, min=-10.0, max=10.0, mean=-1.134),
# (pid=6449)                         'obs': np.ndarray((23, 17), dtype=float32, min=-10.0, max=10.0, mean=-1.013),
# (pid=6449)                         'prev_actions': np.ndarray((23, 6), dtype=float32, min=-2.51, max=2.553, mean=0.062),
# (pid=6449)                         'prev_rewards': np.ndarray((23,), dtype=float32, min=-0.901, max=1.093, mean=-0.001),
# (pid=6449)                         'rewards': np.ndarray((23,), dtype=float32, min=-0.901, max=1.093, mean=0.011),
# (pid=6449)                         't': np.ndarray((23,), dtype=int64, min=0.0, max=22.0, mean=11.0),
# (pid=6449)                         'unroll_id': np.ndarray((23,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=6449)                         'value_targets': np.ndarray((23,), dtype=float32, min=-2.03, max=1.963, mean=0.553),
# (pid=6449)                         'vf_preds': np.ndarray((23,), dtype=float32, min=-0.126, max=0.068, mean=-0.019)},
# (pid=6449)               'type': 'SampleBatch'}}
# (pid=6449)
# (pid=6449) 2019-11-11 11:27:32,441	INFO rollout_worker.py:501 -- Completed sample batch:
# (pid=6449)
# (pid=6449) { 'data': { 'action_logp': np.ndarray((200,), dtype=float32, min=-16.155, max=-5.695, mean=-8.383),
# (pid=6449)             'action_prob': np.ndarray((200,), dtype=float32, min=0.0, max=0.003, mean=0.001),
# (pid=6449)             'actions': np.ndarray((200, 6), dtype=float32, min=-2.93, max=4.091, mean=0.039),
# (pid=6449)             'advantages': np.ndarray((200,), dtype=float32, min=-8.147, max=10.982, mean=-0.592),
# (pid=6449)             'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=6449)             'behaviour_logits': np.ndarray((200, 12), dtype=float32, min=-0.169, max=0.139, mean=0.001),
# (pid=6449)             'dones': np.ndarray((200,), dtype=bool, min=0.0, max=1.0, mean=0.045),
# (pid=6449)             'eps_id': np.ndarray((200,), dtype=int64, min=457267029.0, max=1887030138.0, mean=1385144914.585),
# (pid=6449)             'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=6449)             'new_obs': np.ndarray((200, 17), dtype=float32, min=-10.0, max=10.0, mean=-0.907),
# (pid=6449)             'obs': np.ndarray((200, 17), dtype=float32, min=-10.0, max=10.0, mean=-0.759),
# (pid=6449)             'prev_actions': np.ndarray((200, 6), dtype=float32, min=-2.93, max=4.091, mean=0.051),
# (pid=6449)             'prev_rewards': np.ndarray((200,), dtype=float32, min=-1.555, max=1.618, mean=0.134),
# (pid=6449)             'rewards': np.ndarray((200,), dtype=float32, min=-1.555, max=1.618, mean=0.116),
# (pid=6449)             't': np.ndarray((200,), dtype=int64, min=0.0, max=32.0, mean=10.705),
# (pid=6449)             'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=6449)             'value_targets': np.ndarray((200,), dtype=float32, min=-8.095, max=10.987, mean=-0.616),
# (pid=6449)             'vf_preds': np.ndarray((200,), dtype=float32, min=-0.134, max=0.094, mean=-0.024)},
# (pid=6449)   'type': 'SampleBatch'}
# (pid=6449)
# (pid=6443) 2019-11-11 11:27:32,488	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6450) 2019-11-11 11:27:32,496	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6438) 2019-11-11 11:27:32,485	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6447) 2019-11-11 11:27:32,488	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6436) 2019-11-11 11:27:32,486	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6444) 2019-11-11 11:27:32,488	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6440) 2019-11-11 11:27:32,496	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6445) 2019-11-11 11:27:32,485	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6451) 2019-11-11 11:27:32,499	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6441) 2019-11-11 11:27:32,523	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6437) 2019-11-11 11:27:32,504	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6437) 2019-11-11 11:27:32,544	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6437) Traceback (most recent call last):
# (pid=6437)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6437)     import requests  # `requests` is not part of stdlib.
# (pid=6437)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6437)     import chardet
# (pid=6437) ModuleNotFoundError: No module named 'chardet'
# (pid=6443) 2019-11-11 11:27:32,518	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6443) Traceback (most recent call last):
# (pid=6443)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6443)     import requests  # `requests` is not part of stdlib.
# (pid=6443)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6443)     import chardet
# (pid=6443) ModuleNotFoundError: No module named 'chardet'
# (pid=6450) 2019-11-11 11:27:32,537	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6450) Traceback (most recent call last):
# (pid=6450)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6450)     import requests  # `requests` is not part of stdlib.
# (pid=6450)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6450)     import chardet
# (pid=6450) ModuleNotFoundError: No module named 'chardet'
# (pid=6438) 2019-11-11 11:27:32,521	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6438) Traceback (most recent call last):
# (pid=6438)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6438)     import requests  # `requests` is not part of stdlib.
# (pid=6438)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6438)     import chardet
# (pid=6438) ModuleNotFoundError: No module named 'chardet'
# (pid=6447) 2019-11-11 11:27:32,535	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6447) Traceback (most recent call last):
# (pid=6447)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6447)     import requests  # `requests` is not part of stdlib.
# (pid=6447)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6447)     import chardet
# (pid=6447) ModuleNotFoundError: No module named 'chardet'
# (pid=6439) 2019-11-11 11:27:32,509	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6439) 2019-11-11 11:27:32,545	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6439) Traceback (most recent call last):
# (pid=6439)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6439)     import requests  # `requests` is not part of stdlib.
# (pid=6439)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6439)     import chardet
# (pid=6439) ModuleNotFoundError: No module named 'chardet'
# (pid=6442) 2019-11-11 11:27:32,518	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6444) 2019-11-11 11:27:32,521	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6444) Traceback (most recent call last):
# (pid=6444)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6444)     import requests  # `requests` is not part of stdlib.
# (pid=6444)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6444)     import chardet
# (pid=6444) ModuleNotFoundError: No module named 'chardet'
# (pid=6446) 2019-11-11 11:27:32,517	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6446) 2019-11-11 11:27:32,549	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6446) Traceback (most recent call last):
# (pid=6446)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6446)     import requests  # `requests` is not part of stdlib.
# (pid=6446)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6446)     import chardet
# (pid=6446) ModuleNotFoundError: No module named 'chardet'
# (pid=6440) 2019-11-11 11:27:32,528	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6440) Traceback (most recent call last):
# (pid=6440)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6440)     import requests  # `requests` is not part of stdlib.
# (pid=6440)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6440)     import chardet
# (pid=6440) ModuleNotFoundError: No module named 'chardet'
# (pid=6448) 2019-11-11 11:27:32,505	WARNING policy_client.py:17 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6448) 2019-11-11 11:27:32,537	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6448) Traceback (most recent call last):
# (pid=6448)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6448)     import requests  # `requests` is not part of stdlib.
# (pid=6448)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6448)     import chardet
# (pid=6448) ModuleNotFoundError: No module named 'chardet'
# (pid=6445) 2019-11-11 11:27:32,515	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6445) Traceback (most recent call last):
# (pid=6445)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6445)     import requests  # `requests` is not part of stdlib.
# (pid=6445)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6445)     import chardet
# (pid=6445) ModuleNotFoundError: No module named 'chardet'
# (pid=6451) 2019-11-11 11:27:32,531	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6451) Traceback (most recent call last):
# (pid=6451)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6451)     import requests  # `requests` is not part of stdlib.
# (pid=6451)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6451)     import chardet
# (pid=6451) ModuleNotFoundError: No module named 'chardet'
# (pid=6441) 2019-11-11 11:27:32,555	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6441) Traceback (most recent call last):
# (pid=6441)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6441)     import requests  # `requests` is not part of stdlib.
# (pid=6441)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6441)     import chardet
# (pid=6441) ModuleNotFoundError: No module named 'chardet'
# (pid=6436) 2019-11-11 11:27:32,567	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6436) Traceback (most recent call last):
# (pid=6436)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6436)     import requests  # `requests` is not part of stdlib.
# (pid=6436)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6436)     import chardet
# (pid=6436) ModuleNotFoundError: No module named 'chardet'
# (pid=6442) 2019-11-11 11:27:32,564	ERROR web_server.py:29 -- Couldn't import `requests` library. Be sure to install it on the client side.
# (pid=6442) Traceback (most recent call last):
# (pid=6442)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/web_server.py", line 26, in <module>
# (pid=6442)     import requests  # `requests` is not part of stdlib.
# (pid=6442)   File "/home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/requests/__init__.py", line 44, in <module>
# (pid=6442)     import chardet
# (pid=6442) ModuleNotFoundError: No module named 'chardet'
# (pid=6437) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6437)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6437) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6437)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6437) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6437)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6437) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6437)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6437) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6437)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6437) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6437)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6443) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6443)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6443) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6443)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6443) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6443)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6443) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6443)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6443) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6443)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6443) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6443)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6438) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6438)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6438) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6438)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6438) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6438)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6438) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6438)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6438) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6438)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6438) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6438)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6447) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6447)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6447) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6447)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6447) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6447)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6447) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6447)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6447) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6447)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6447) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6447)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6439) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6439)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6439) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6439)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6439) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6439)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6439) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6439)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6439) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6439)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6439) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6439)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6444) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6444)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6444) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6444)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6444) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6444)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6444) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6444)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6444) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6444)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6444) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6444)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6440) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6440)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6440) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6440)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6440) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6440)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6440) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6440)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6440) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6440)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6440) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6440)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6448) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6448)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6448) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6448)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6448) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6448)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6448) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6448)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6448) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6448)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6448) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6448)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6445) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6445)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6445) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6445)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6445) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6445)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6445) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6445)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6445) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6445)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6445) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6445)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6451) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6451)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6451) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6451)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6451) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6451)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6451) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6451)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6451) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6451)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6451) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6451)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6442) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6442)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6442) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6442)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6442) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6442)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6442) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6442)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6442) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6442)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6442) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6442)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6446) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6446)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6446) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6446)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6446) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6446)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6446) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6446)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6446) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6446)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6446) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6446)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6441) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6441)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6441) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6441)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6441) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6441)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6441) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6441)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6441) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6441)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6441) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6441)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6450) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6450)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6450) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6450)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6450) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6450)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6450) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6450)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6450) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6450)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6450) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6450)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=6436) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6436)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=6436) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6436)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=6436) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6436)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=6436) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6436)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=6436) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6436)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=6436) /home/sgillen/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=6436)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2019-11-11 11:27:36,629	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/fc_out/kernel:0' shape=(17, 12) dtype=float32>
# 2019-11-11 11:27:36,630	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/fc_out/bias:0' shape=(12,) dtype=float32>
# 2019-11-11 11:27:36,630	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/value_out/kernel:0' shape=(17, 1) dtype=float32>
# 2019-11-11 11:27:36,631	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/value_out/bias:0' shape=(1,) dtype=float32>
# 2019-11-11 11:27:36,635	INFO multi_gpu_impl.py:146 -- Training on concatenated sample batches:
#
# { 'inputs': [ np.ndarray((4000, 6), dtype=float32, min=-4.363, max=4.397, mean=0.019),
#               np.ndarray((4000,), dtype=float32, min=-2.001, max=2.142, mean=0.004),
#               np.ndarray((4000, 17), dtype=float32, min=-10.0, max=10.0, mean=-0.993),
#               np.ndarray((4000,), dtype=float32, min=-18.174, max=-5.469, mean=-8.576),
#               np.ndarray((4000, 6), dtype=float32, min=-4.363, max=4.397, mean=0.015),
#               np.ndarray((4000,), dtype=float32, min=-3.256, max=6.113, mean=-0.0),
#               np.ndarray((4000, 12), dtype=float32, min=-0.19, max=0.147, mean=0.004),
#               np.ndarray((4000, 17), dtype=float32, min=-10.0, max=10.0, mean=-0.993),
#               np.ndarray((4000, 6), dtype=float32, min=-4.363, max=4.397, mean=0.019),
#               np.ndarray((4000,), dtype=float32, min=-2.001, max=2.142, mean=0.004),
#               np.ndarray((4000,), dtype=float32, min=-14.357, max=22.529, mean=-1.513),
#               np.ndarray((4000,), dtype=float32, min=-0.166, max=0.123, mean=-0.035)],
#   'placeholders': [ <tf.Tensor 'default_policy/action:0' shape=(?, 6) dtype=float32>,
#                     <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/observation:0' shape=(?, 17) dtype=float32>,
#                     <tf.Tensor 'default_policy/action_logp:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/actions:0' shape=(?, 6) dtype=float32>,
#                     <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 12) dtype=float32>,
#                     <tf.Tensor 'default_policy/observation:0' shape=(?, 17) dtype=float32>,
#                     <tf.Tensor 'default_policy/action:0' shape=(?, 6) dtype=float32>,
#                     <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>],
#   'state_inputs': []}
#
# 2019-11-11 11:27:36,635	INFO multi_gpu_impl.py:191 -- Divided 4000 rollout sequences, each of length 1, among 1 devices.
#   0%|          | 0/500 [00:05<?, ?it/s]
# 2019-11-11 11:27:37,195	ERROR import_thread.py:89 -- ImportThread: Connection closed by server.
# 2019-11-11 11:27:37,196	ERROR worker.py:1781 -- listen_error_messages_raylet: Connection closed by server.
# 2019-11-11 11:27:37,196	ERROR worker.py:1681 -- print_logs: Connection closed by server.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4b3f79af9f5e> in <module>
#      34 for i in trange(500):
#      35    # Perform one iteration of training the policy with ARS
# ---> 36     result = trainer.train()
#      37
#      38 checkpoint = trainer.save()
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/ray/rllib/agents/trainer.py in train(self)
#     404         for _ in range(1 + MAX_WORKER_FAILURE_RETRIES):
#     405             try:
# --> 406                 result = Trainable.train(self)
#     407             except RayError as e:
#     408                 if self.config["ignore_worker_failures"]:
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/ray/tune/trainable.py in train(self)
#     174
#     175         start = time.time()
# --> 176         result = self._train()
#     177         assert isinstance(result, dict), "_train() needs to return a dict."
#     178
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py in _train(self)
#     127             start = time.time()
#     128             while True:
# --> 129                 fetches = self.optimizer.step()
#     130                 if after_optimizer_step:
#     131                     after_optimizer_step(self, fetches)
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py in step(self)
#     202                         batch_fetches = optimizer.optimize(
#     203                             self.sess, permutation[batch_index] *
# --> 204                             self.per_device_batch_size)
#     205                         for k, v in batch_fetches[LEARNER_STATS_KEY].items():
#     206                             iter_extra_fetches[k].append(v)
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_impl.py in optimize(self, sess, batch_index)
#     258             fetches.update(tower.loss_graph._get_grad_and_stats_fetches())
#     259
# --> 260         return sess.run(fetches, feed_dict=feed_dict)
#     261
#     262     def get_common_loss(self):
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1131
#    1132           feed_dict_tensor[subfeed_t] = np_val
# -> 1133           feed_map[compat.as_bytes(subfeed_t.name)] = (subfeed_t, subfeed_val)
#    1134
#    1135     # Create a fetch handler to take care of the structure of fetches.
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in name(self)
#     345   def name(self):
#     346     """The string name of this tensor."""
# --> 347     if not self._op.name:
#     348       raise ValueError("Operation was not named: %s" % self._op)
#     349     return "%s:%d" % (self._op.name, self._value_index)
#
# ~/miniconda3/envs/ray/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in name(self)
#    1928   def name(self):
#    1929     """The full name of this operation."""
# -> 1930     return c_api.TF_OperationName(self._c_op)
#    1931
#    1932   @property
#
# KeyboardInterrupt:

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

env = gym.make(env_name)
obs = env.reset()

action_hist = []
state_hist  = []
reward_hist = []

done = False
while not done:
    actions = trainer.compute_action(obs.flatten())
    obs, reward, done, _ = env.step(np.asarray(actions))
    action_hist.append(np.copy(np.clip(actions, -10, 10)))
    state_hist.append(np.copy(obs))
    reward_hist.append(np.copy(reward))
    if done:
        break


print(sum(reward_hist))
plt.plot(action_hist)
plt.figure()
plt.plot(state_hist)
