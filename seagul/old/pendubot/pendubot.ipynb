# %%
# Force keras to use the CPU becuase it's actually faster for this size network
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBE_DEVICES"] = ""

import numpy as np
from numpy import cos, sin, pi

from numba import jit

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.constraints import max_norm

import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import HTML

import time

from scipy import integrate

import pendubot_class as pb
# Out:
# /Users/sgillen/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
bot = pb.Acrobot()

#@jit(nopython=False)
#def control(t,q):
    #return 1

#bot.control = control

# time step
t = np.array([0.0, 20])

rad = np.pi / 180

#y = np.zeros((num_t, num_states, num_trials))

th1 = pi/2 + .1
th2 = 0.1
dth1 = 0.0
dth2 = 0.0

# initial state
state = np.array([th1, th2, dth1, dth2])

# integrate the ODE using scipy.integrate.

start = time.time()
sol = integrate.solve_ivp(bot.derivs, t, state)
end = time.time()
plt.plot(sol.y.T)

ani = bot.animate_pend(sol.t, sol.y)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img75863d3ed6304c07978571dec93e64fe">
#     <br>
#     <input id="_anim_slider75863d3ed6304c07978571dec93e64fe" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim75863d3ed6304c07978571dec93e64fe.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim75863d3ed6304c07978571dec93e64fe.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select75863d3ed6304c07978571dec93e64fe" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img75863d3ed6304c07978571dec93e64fe";
#     var slider_id = "_anim_slider75863d3ed6304c07978571dec93e64fe";
#     var loop_select_id = "_anim_loop_select75863d3ed6304c07978571dec93e64fe";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAFeFJREFUeJzt3X1wlOWhhvF7kwiCCVCVCMliBwxd\
# 4uZj+cZTi2FKSJEICahDZWodtLG11apDrB1Oj9KREU6nPWXKtOmOOpWOHwMVhVNsnEFc61QtBIMx\
# csikDGgSREGJECRkSd7zR5poCEKE3X2eJ7l+M06y6ybeRuHK++7Lxud5nicAAByTZHoAAADng4AB\
# AJxEwAAATiJgAAAnETAAgJMIGADASQQMAOAkAgYAcBIBAwA4iYABAJxEwAAATiJgAAAnETAAgJMI\
# GADASQQMAOAkAgYAcBIBAwA4iYABAJxEwAAATiJgAAAnETAAgJMIGADASQQMAOAkAgYAcBIBAwA4\
# iYABAJxEwAAATiJgAAAnETAAgJMIGADASQTMMq2trZo2bZry8/MVDAb10EMPmZ4EAFbyeZ7nmR6B\
# z3mep+PHjys1NVXRaFTXXnut1qxZoxkzZpieBgBW4QjMMj6fT6mpqZKkaDSqaDQqn89neBUA2IeA\
# Wai9vV2hUEjp6ekqLCzU9OnTTU8CAOukmB6A3pKTk7Vr1y41NzertLRUtbW1ysnJ6fGYcDiscDgs\
# SXr33Xd15ZVXmph6Rh0dHUpKsud7I/acm22bbNvz8ccf6/Dhw6Zn4DQ8B2a5FStW6JJLLtGyZcu+\
# 9DGBQEB1dXUJXHV2kUhEBQUFpmd0Y8+52bbJtj1TpkxRVVWV6Rk4jT3f4kCSdOjQITU3N0uSTpw4\
# oa1bt2rChAmGVwGAfTiFaJkPPvhA3//+99Xe3q6Ojg7dfPPNKi4uNj0LAKxDwCyTl5en6upq0zMA\
# wHqcQgQAOImAAQCcRMAAAE4iYAAAJxEwAICTCBgAwEkEDADgJAIGAHASARtgmpub9fvf/7779oED\
# B3TjjTcaXNRp586dys3NVVZWlu655x6d7SU6d+zYoeTkZP3lL39J4EIAtiFgA8zpAcvIyLAiBD/6\
# 0Y8UDodVX1+v+vp6VVZWnvFx7e3t+tnPfqaioqIELwRgGwI2wDz44IPau3evQqGQysvLtX///u4f\
# 1fKnP/1JJSUluuGGGzR27FitXbtWv/nNbzRx4kTNmDFDn3zyiSRp7969+s53vqPJkyfrW9/6lvbs\
# 2XNBmz744AMdPXpU11xzjXw+n2699Va98MILZ3zs7373Oy1atEjp6ek9Pn7mzJkKhULKycnRa6+9\
# dkF7ALiB10IcYFatWqXa2lrt2rVLkrR///4ef7+2tlbV1dVqbW1VVlaWVq9ererqat13331at26d\
# 7r33XpWVlamiokLjx4/XP//5T911113atm1bj8/zyiuv6L777uv1zx86dKhef/31Hvc1NTXJ7/d3\
# 3/b7/Wpqaur1sU1NTXr++ee1bds27dixo/v+p59+WkVFRVq+fLna29v12WeffeWvCwD3EDD0MGvW\
# LKWlpSktLU3Dhw/XDTfcIEnKzc1VTU2NWlpa9Prrr+umm27q/piTJ0+e8fN0RfJczvR8l8/n63Xf\
# vffeq9WrVys5ObnH/VOnTtXSpUsVjUZVUlKiUCjUp38uALcRMPQwePDg7veTkpK6byclJenUqVPq\
# 6OjQiBEjzhmnr3IE5vf71djY2H27sbFRGRkZvT62qqpKixcvliQdPnxYL774olJSUlRSUqK///3v\
# 2rJli773ve+pvLxct956a9//pQE4iYANMGlpaTp27Nh5f/ywYcM0duxYbdiwQTfddJM8z1NNTY3y\
# 8/N7PO6rHIGNHj1aaWlpevPNNzV9+nStW7dOd999d6/H7du3r/v92267TcXFxSopKdF7772nzMxM\
# /eAHP9Dx48f11ltvETBgAOAijgHmsssu0ze/+U3l5OSovLz8vD7HU089pccff1z5+

# %%
num_trials = 1
num_states = 4
num_t = len(t)
y = np.zeros((num_t, num_states, num_trials))


for i in range(num_trials):
    # initial conditions
    th1 = pi/2
    th2 = 0.0
    dth1 = 0.1#2*(i/num_trials) - 1  # an initial velocity, triggers the swing up control
    dth2 = 0.0

    # initial state
    state = np.array([th1, th2, dth1, dth2])

    # integrate the ODE using scipy.integrate.
    u_hist = []
    y[:, :, i] = integrate.odeint(derivs, state, t)


u = np.zeros((num_t, num_trials))
for i in range(num_trials):
    for t in range(num_t):
        u[t,i] = control(y[t,:,i]) 

        
ani = animate_pend(y[:,:,0])
HTML(ani.to_jshtml())

# %%
# Create our LSTM network

look_back = 1

with tf.variable_scope('pi/pol/'):
    model = Sequential()
    model.add(LSTM(12, input_shape=(4,look_back)))
    #model.add(LSTM(4, input_shape =(12,look_back)))
    model.add(Dense(1))

    #model.add(Dense(2))
    

model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(y, u, epochs=500, verbose=0)
# %matplotlib inline
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %%
# This is a closure that returns our NN controller
def make_controller(model):
    def nn_controller(q):
        if (q[0] < 140 * rad) or (q[0] > 220 * rad):
            return model.predict(q.reshape((1,4,1)))
        else:
            # balancing
            # LQR: K values from MATLAB
            k1 = 140.560
            k2 = -3.162
            k3 = 41.772
            k4 = -8.314
            u = -(k1 * (q[0] - pi) + k2 * q[1] + k3 * q[2] + k4 * q[3])
            return u
        
    return nn_controller

# %%
control = make_controller(model)

# initial conditions
theta = 0
x = 0
th_dot = .01 # an initial velocity, triggers the swing up control
xdot = 0.0
t = np.arange(0.0, 20, dt)


# initial state
state = np.array([theta, x, th_dot, xdot])

# integrate the ODE using scipy.integrate.
y_test = integrate.odeint(derivs, state, t)

#ani = animate_pend(y_test)
#HTML(ani.to_html5_video())

# %%
def run_swingup():
    control = make_controller(model)
    
    # initial conditions
    theta = 0
    x = 0
    th_dot = .01 # an initial velocity, triggers the swing up control
    xdot = 0.0
    t = np.arange(0.0, 20, dt)


    # initial state
    state = np.array([theta, x, th_dot, xdot])

    # integrate the ODE using scipy.integrate.
    y_test = integrate.odeint(derivs, state, t)

    #ani = animate_pend(y_test)
    #HTML(ani.to_html5_video())

# %%
control = make_controller(model)

# initial conditions
theta = 0
x = 0
th_dot = .01 # an initial velocity, triggers the swing up control
xdot = 0.0
t_index = np.arange(0.0, 2, dt)


# initial state
state = np.array([theta, x, th_dot, xdot])

# integrate the ODE using scipy.integrate.
# Fill in our u after the fact..
y_test = integrate.odeint(derivs, state, t_index)
u_test = np.zeros((y.shape[0],1))
for t in range(num_t):
        u_test[t] = control(y[t]) 

        
data = np.concatenate((y_test, u_test),axis=1)
names = ['theta','x','thetadot','xdot','u']
yf = pd.DataFrame(data = data, index = t_index, columns = names)


ani = animate_pend(y_test)
HTML(ani.to_html5_video())

# %%
plt.plot(yf['state','theta'])
old_theta = yf['state','theta']

# %%
new_theta = yf['theta']

# %%
np.all(old_theta == new_theta)

# %%
N_train = 1000
from numpy.random import choice
one_indexes = choice(a=N_train, size=int(N_train / 2), replace=False)
X_train[one_indexes, 0] = 1  # very long term memory.

# %%
# messing with multiindexing 
# TODO probably move this to the misc folder, preferably as a more complete example than this one.

names = [
    ('state', 'theta'),
    ('state', 'x'),
    ('state', 'thetadot'),
    ('state', 'xdot'),
    ('control' ,'u')
]

yf = pd.DataFrame(data = data, index = t_index, columns=pd.MultiIndex.from_tuples(names))
