# %%
import numpy as np
from numpy.fft import fft
from matplotlib.pyplot import plot, figure

# %matplotlib inline


#x = np.arange(0,1,9.01)
#x = np.concatenate((np.ones((50,1)), np.zeros((50,1))))

t = np.arange(0,10,.01)

print(len(t))
print(len(np.zeros((1,50))))

x = np.concatenate((np.sin(t), np.zeros((50))))


X = fft(x)
plot(x)
figure()
plot(np.abs(X))
# Out:
# 1000
# 1

# %%
print(len(t))
print(len(np.zeros((1,50))))

print(t.size)
print(np.zeros((1,50)).size)
# Out:
# 1000
# 1
# 1000
# 50
