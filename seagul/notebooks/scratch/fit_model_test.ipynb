# %%
from seagul.nn import MLP, fit_model
import torch
import matplotlib.pyplot as plt

# %%
train_size = 40000

input_size = 1
output_size = 1
hidden_size = 12
num_layers = 2

X = torch.randn(train_size,input_size)
Y = 2*X

net = MLP(input_size, output_size, hidden_size, num_layers)

# %%
hist = fit_model(net,X,Y,5)
plt.plot(hist)
# Out:
# 100%|██████████| 5/5 [00:18<00:00,  3.71s/it]

# %%
X_test = torch.randn(train_size,input_size)
Y_test = 2*X_test
Y_pred = net(X_test)

test_error = (Y_test - Y_pred)**2
print(test_error.mean())
# Out:
# tensor(3.9946, grad_fn=<MeanBackward0>)
