# %%
from seagul.baselines.run import run_and_save, load_model
import pandas as pd
import matplotlib.pyplot as plt

arg_dict = {
    #'env': 'bullet_car_ast-v0',
    #'env': 'Walker2d-v2',
    #'env': 'Hopper-v2', # Continous
    "env": "su_cartpole_push-v0",
    "alg": "ppo2",
    "network": "mlp",
    "num_timesteps": "1e7",
    "num_env": "8",
    "num_layers": "2",
    "num_hidden": "12",
}

# run_name ='fps_test_noball'

run_name = "push_baseline_2_12"
run_desc = "getting baseline for the su environment with a smaller network"
run_and_save(arg_dict, run_name=run_name, description=run_desc, base_path="/data/push_baselines/")
# Out:
# Logging to /tmp/openai-2019-08-27-17-16-24-234773
# Logging to /home/sgillen/work/seagul/seagul/notebooks/switching/data/push_baselines/push_baseline_2_12/
# env_type: classic_control
# Training ppo2 on classic_control:su_cartpole_push-v0 with arguments
# {'num_layers': 2, 'num_hidden': 12, 'network': 'mlp'}
# ---------------------------------------
# | approxkl           | 3.6449292e-06  |
# | clipfrac           | 0.0            |
# | eplenmean          | 1.5e+03        |
# | eprewmean          | 606            |
# | explained_variance | -0.00466       |
# | fps                | 3534           |
# | nupdates           | 1              |
# | policy_entropy     | 1.4190161      |
# | policy_loss        | -6.8650043e-06 |
# | serial_timesteps   | 2048           |
# | time_elapsed       | 4.64           |
# | total_timesteps    | 16384          |
# | value_loss         | 81.73885       |
# ---------------------------------------
# ---------------------------------------
# ...

# %%
from seagul.baselines.run import run_and_save, load_model
import pandas as pd
import matplotlib.pyplot as plt

save_path = "./data/push_baselines/push_baseline2"
#model, env = load_model(save_path) # This is loading the trained model for analysis
t_data = pd.read_csv(save_path + '/progress.csv' ) # This is data about the training
plt.plot(t_data['eprewmean'])

# %%
t_data
